# %%
import pandas as pd

db = pd.read_csv("Final_Project/Natural_Environment_Conditions_2010.csv", sep=",")

avg_num_trees = db["# Street Trees"].mean()

avg_num_parkSpace = db["Park Space (acres/1000 pers.)"].mean()

mask_tree = db["# Street Trees"] > avg_num_trees
# db[mask_tree] --> neighborhoods thats have more than avg num of trees

mask_parkSpace = db["Park Space (acres/1000 pers.)"] > avg_num_parkSpace

# db[mask_parkSpace] --> neighborhoods thats have more than avg num of park space...

mask = (db["# Street Trees"] > avg_num_trees) & (db["Park Space (acres/1000 pers.)"] > avg_num_parkSpace)

db[mask]
# Out:
#            Neighborhood  Sector #  Population (2010)  Land Area (acres)  \
# 39        Highland Park        12               6395             744.32
# 56          North Shore        16                303             193.92
# 60          Perry North         2               4050             775.68
# 76  Squirrel Hill South        10              15110            1709.44
#
#     Landslide Prone (% land area)  Undermined (% land area)  \
# 39                       0.164291                  0.000000
# 56                       0.000000                  0.000000
# 60                       0.589862                  0.033226
# 76                       0.219201                  0.087825
#
#     Flood Plain (% land area)  # Street Trees  Park Space (acres)  \
# 39                   0.003175            1012             350.732
# 56                   0.819585             400              10.730
# 60                   0.000000             402             258.636
# ...
